# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import numpy as np
import random
from PIL import Image, ImageEnhance
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16
from sklearn.utils import shuffle

# %%
# Directories for training and testing data
train_dir = '/content/drive/MyDrive/MRI images/Training/'
test_dir = '/content/drive/MyDrive/MRI images/Testing/'

# %%
# load and shuffle the train data
train_paths=[]
train_labels=[]
for label in os.listdir(train_dir):
  for image in os.listdir(os.path.join(train_dir, label)):
    train_paths.append(os.path.join(train_dir, label, image))
    train_labels.append(label)

train_paths,train_labels=shuffle(train_paths, train_labels)

# load and shuffle the test data
test_paths=[]
test_labels=[]
for label in os.listdir(test_dir):
  for image in os.listdir(os.path.join(test_dir, label)):
    test_paths.append(os.path.join(test_dir, label, image))
    test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)
train_paths
# Out:
# ['/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0953.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0705.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0660.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1120.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1211.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0086.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0889.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0201.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0626.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0910.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0684.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1436.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1237.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0629.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1054.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0886.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0401.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1446.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0779.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1451.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1456.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-meTr_0004.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0134.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1023.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0980.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0763.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1382.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0201.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0187.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1296.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0436.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0441.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1336.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0772.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0960.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0778.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1222.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1180.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0884.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0226.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0372.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1346.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0307.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0320.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1243.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1039.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0329.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0759.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1024.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0073.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1074.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0149.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0391.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1237.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0615.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0291.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0295.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1056.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1242.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0149.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0585.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0891.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0209.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1293.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1435.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0704.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0453.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1194.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0504.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1188.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0252.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0922.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1058.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0717.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0013.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0926.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0935.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1379.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0264.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0748.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0107.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1275.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1303.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0805.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0091.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0263.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0569.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0282.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0834.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1507.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0125.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1227.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0575.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0963.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0557.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1095.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0515.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1501.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0233.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1563.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1285.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0182.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1222.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1266.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0064.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0481.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0431.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0981.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0289.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0431.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0506.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1009.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0696.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1304.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0869.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0267.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0816.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0752.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1546.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0953.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0400.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1368.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1301.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0491.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0807.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0253.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0552.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0536.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0145.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1187.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0591.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0289.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0765.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1019.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1282.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0626.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0237.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1492.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0306.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0932.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0966.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0393.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0328.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1123.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0121.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1188.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0676.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1434.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1017.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0207.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0786.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0535.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1431.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0658.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0807.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1027.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0425.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0643.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1232.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0387.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1030.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0633.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0946.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0664.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0570.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0625.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0138.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0611.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0771.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0918.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1178.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1339.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0475.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0432.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0011.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0780.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0539.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0810.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1477.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0699.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1027.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1007.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1131.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0303.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0924.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0783.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0294.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1409.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1074.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1156.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0912.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1332.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0845.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1179.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-piTr_0006.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1318.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0808.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0022.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0456.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0120.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0178.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0667.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0450.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0063.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0639.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1391.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0248.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1263.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1215.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0962.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0451.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0861.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0578.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1000.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0455.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0395.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0577.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1198.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0851.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0956.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0246.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0933.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0576.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1312.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0047.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1528.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0791.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0252.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1040.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0673.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0850.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0639.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0653.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0879.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0083.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1231.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0397.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1206.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0521.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0527.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0515.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1270.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1237.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1366.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0433.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1476.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0503.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0496.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0090.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1205.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0665.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0467.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0308.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0913.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0513.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1198.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0189.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0355.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1160.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0300.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0376.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1043.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0340.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0763.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0439.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0173.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0901.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1265.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0133.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1100.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1107.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1340.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0537.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0990.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0678.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0796.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0339.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0135.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0422.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0037.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1001.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_
jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1103.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0787.jpg',
# ...
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0209.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1023.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0551.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0108.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0374.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0601.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0680.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0976.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1296.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0265.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0040.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0740.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0042.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0564.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0917.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0882.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1568.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1215.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0068.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0034.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0590.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0929.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0216.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1103.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0984.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0605.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0105.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0436.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1201.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0610.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1126.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0986.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0734.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0653.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1210.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0462.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1389.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1291.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0373.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0237.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0864.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0153.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1355.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0049.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0868.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0936.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0242.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1437.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1231.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1001.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1250.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1099.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0142.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0234.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0751.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1092.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1119.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0565.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1080.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0407.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0415.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0894.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1034.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0982.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1204.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0967.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0825.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0012.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1388.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0800.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0601.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0466.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0382.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0667.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1153.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0896.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0505.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1044.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0115.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0255.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0737.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1307.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0951.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0151.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0180.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0385.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0022.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0798.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0916.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1517.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0361.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0991.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1136.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0530.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0866.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0806.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0224.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1285.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1009.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0509.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0137.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0134.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0185.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0603.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0078.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0193.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0924.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0702.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0382.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0584.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0525.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0515.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1295.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0113.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0021.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0124.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0824.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1103.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0396.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0757.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0419.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0486.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1197.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0847.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0397.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0637.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0585.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1296.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0327.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0142.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0332.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0459.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0809.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0082.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0202.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1434.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0986.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0084.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0638.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0312.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0196.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1399.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0564.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1264.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1093.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1097.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1037.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0229.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0590.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0614.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0604.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0852.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0890.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0911.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1539.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0204.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0835.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1240.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0178.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1287.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0489.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0944.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0194.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1287.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0148.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0035.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0329.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1250.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0296.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0246.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0788.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0351.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0163.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0689.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0602.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1319.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1301.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1079.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0376.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1242.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1158.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0272.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1072.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1320.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1364.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0407.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0293.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1152.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0895.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0923.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1558.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0523.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1234.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1094.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0638.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1317.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1134.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0558.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1076.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0411.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0870.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1175.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0853.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0569.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1388.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1076.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0426.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0455.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0101.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1230.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0876.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0565.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1157.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_1088.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0015.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_1390.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0413.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0219.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_1236.jpg',
#  '/content/drive/MyDrive/MRI images/Training/meningioma/Tr-me_0276.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_0125.jpg',
#  '/content/drive/MyDrive/MRI images/Training/glioma/Tr-gl_1146.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0395.jpg',
#  '/content/drive/MyDrive/MRI images/Training/pituitary/Tr-pi_0241.jpg',
#  '/content/drive/MyDrive/MRI images/Training/notumor/Tr-no_0602.jpg',
#  ...]

# %%
# Data Visualization
import random
import matplotlib.pyplot as plt

# select random indices
random_indices = random.sample(range(len(train_paths)),10)

# create a figure to display images in 2 rows
fig, axes= plt.subplots(2,5, figsize=(15,6))
axes = axes.ravel()

for i, idx in enumerate(random_indices):
  img_path=train_paths[idx]
  img=Image.open(img_path)

  axes[i].imshow(img)
  axes[i].axis('off')
  axes[i].set_title(f"Label : {train_labels[idx]}", fontsize=18)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# model architecture
IMAGE_SIZE= 128
base_model = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE,3), include_top=False, weights='imagenet')

# freeze all layers of the VGG16 base model
for layer in base_model.layers:
  layer.trainable = False

base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# build model
model = Sequential()
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))   # input layer
model.add(base_model)     # VGG16 model
model.add(Flatten())
model.add(Dropout(0.3))

model.add(Dense(len(os.listdir(train_dir)), activation='softmax'))

# compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# parameters
batch_size = 20
steps= int(len(train_paths)/batch_size)
epochs= 5

# train model
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    train_dir,  # misalnya '/content/dataset/Training'
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='sparse',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation'
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Found 4571 images belonging to 4 classes.
# Found 1142 images belonging to 4 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3380s 15s/step - loss: 0.5332 - sparse_categorical_accuracy: 0.7952 - val_loss: 0.7618 - val_sparse_categorical_accuracy: 0.7618
# Epoch 2/5
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - loss: 0.1977 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.4520 - val_sparse_categorical_accuracy: 0.8415
# Epoch 3/5
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - loss: 0.1123 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.4901 - val_sparse_categorical_accuracy: 0.8398
# Epoch 4/5
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - loss: 0.0748 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.6664 - val_sparse_categorical_accuracy: 0.8424
# Epoch 5/5
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.5121 - val_sparse_categorical_accuracy: 0.8634

# %%
from tensorflow.keras.callbacks import EarlyStopping

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

# lalu tambahkan ke model.fit()
model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,  # boleh lebih karena akan berhenti otomatis
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 30s 130ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.5840 - val_sparse_categorical_accuracy: 0.8651
# Epoch 2/20
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.6044 - val_sparse_categorical_accuracy: 0.8651
# Epoch 3/20
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.6497 - val_sparse_categorical_accuracy: 0.8660

# %%
import os
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set parameter
IMAGE_SIZE = 128
BATCH_SIZE = 32
EPOCHS = 5
TRAIN_DIR = '/content/drive/MyDrive/MRI images/Training/'  # sesuaikan path dataset training kamu

# Load base model VGG16 tanpa top layer, dengan bobot imagenet
base_model = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, weights='imagenet')

# Freeze semua layer base model dulu
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze beberapa layer atas (misal 3 layer terakhir)
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# Bangun model akhir
model = Sequential([
    Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
    base_model,
    Flatten(),
    Dropout(0.3),
    Dense(len(os.listdir(TRAIN_DIR)), activation='softmax')  # jumlah kelas otomatis
])

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

# Buat ImageDataGenerator dengan augmentasi dan split validasi
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    zoom_range=0.2,
    validation_split=0.2
)

# Load data training
train_generator = datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    subset='training',
    shuffle=True
)

# Load data validasi
val_generator = datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    subset='validation',
    shuffle=False
)

# Mulai training dengan opsi workers untuk percepat data loading
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1142 images belonging to 4 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 77s 469ms/step - loss: 0.6852 - sparse_categorical_accuracy: 0.7085 - val_loss: 0.5981 - val_sparse_categorical_accuracy: 0.7776
# Epoch 2/5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 52s 360ms/step - loss: 0.2963 - sparse_categorical_accuracy: 0.8928 - val_loss: 0.5109 - val_sparse_categorical_accuracy: 0.8091
# Epoch 3/5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 53s 370ms/step - loss: 0.2202 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.4095 - val_sparse_categorical_accuracy: 0.8529
# Epoch 4/5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 52s 361ms/step - loss: 0.1727 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.4819 - val_sparse_categorical_accuracy: 0.8406
# Epoch 5/5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 51s 358ms/step - loss: 0.1625 - sparse_categorical_accuracy: 0.9376 - val_loss: 0.4361 - val_sparse_categorical_accuracy: 0.8529

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt  # pastikan sudah import

plt.figure(figsize=(8,4))   # figsize harus tuple (lebar, tinggi)
plt.grid(True)
plt.plot(history.history['sparse_categorical_accuracy'], '.g-', linewidth=2, label='Train Accuracy')
plt.plot(history.history['loss'], '.r-', linewidth=2, label='Train Loss')
plt.title('Model Training History')
plt.legend()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/MRI images/Testing/',
    target_size=(128, 128),
    batch_size=20,
    class_mode='sparse',
    shuffle=False
)

test_labels = test_generator.classes  # array of integer labels
# Out:
# Found 1311 images belonging to 4 classes.

# %%
import os

test_dir = '/content/drive/MyDrive/MRI images/Testing/'  # ganti dengan path folder test kamu

test_paths = []
test_labels = []

for label_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, label_name)
    if os.path.isdir(class_dir):
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            test_paths.append(img_path)
            test_labels.append(label_name)

print(f"Found {len(test_paths)} test images belonging to {len(set(test_labels))} classes.")
# Out:
# Found 1311 test images belonging to 4 classes.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix




# Encode label ke angka
le = LabelEncoder()
test_labels_encoded = le.fit_transform(test_labels)

# Load test images
test_images = open_images(test_paths, image_size=128)

# Predict
test_predictions = model.predict(test_images)
predicted_classes = np.argmax(test_predictions, axis=1)

# Classification Report
print("Classification Report:")
print(classification_report(test_labels_encoded, predicted_classes, target_names=le.classes_))

# Confusion Matrix
cm = confusion_matrix(test_labels_encoded, predicted_classes)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.94      0.86      0.90       300
#   meningioma       0.84      0.86      0.85       306
#      notumor       0.97      0.95      0.96       405
#    pituitary       0.89      0.97      0.93       300
#
#     accuracy                           0.91      1311
#    macro avg       0.91      0.91      0.91      1311
# weighted avg       0.91      0.91      0.91      1311

# %%
# ROC Curve Plot
class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']
n_classes = len(class_names)

y_test_bin = label_binarize(test_labels_encoded, classes=range(n_classes))
y_score = model.predict(test_images)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2,
             label=f'ROC curve of class {class_names[i]} (area = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !ls
# Out:
# drive  mode.h5	model.h5  my_model.keras  sample_data

# %%
model.save('my_model.keras')

# %%
from google.colab import files
files.download('/content/model.h5')
